# %% [markdown]
# <a href="https://colab.research.google.com/github/ulvem/Time-to-Practice-Pandas-1-10/blob/main/Time_to_Practice_Pandas_0_with_partial_solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### **<font color='#306998'>TASK </font><font color='#ffd33b'> 1-10</font>**
#
# Download `chipotle.tsv` file from the following kaggle site:
# https://www.kaggle.com/datasets/navneethc/chipotle
#
# Upload it to your Google Drive, mount it and load the data.
#
# *Hint: you can copy the path to the file or change the working directory and then use just the file name with .tsv extenstion.*

# %%
import pandas as pd
from google.colab import drive
chipotle = pd.read_csv("chipotle.tsv", sep="\t")
chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# <img src="data:image/png;base64,..." alt="ogo" width="150" align='right'/>
#
# ## Display data
#
# After the data is loaded, the next step is to display it and you can do it in many ways:
# * simply print out what will fit on the screen with `df` (here `chipotle`)
# * `df.head(n)` - displays the first n data records (5 by default)
# * `df.tail(n)` - displays the last n data records (5 by default)
# * `df.sample(n)` - displays n randomly chosen data records (1 by default)
# * `df[“column”]` or `df.column` - displays a given column (as `pd.Series()`)
#     * note that so-called the dot-notation is possible only for column names without whitespace characters❗
# * `df[[“column”]]` - displays a given column (as `pd.DataFrame()`)
# * `df[[“column1”, “column2”]]` - displays several columns
#     * note that you cannot specify multiple columns with single-square brackets notation❗
# * `df.index` - displays indexes
# * `df.columns` - displays column names
# * `df.info()` - general information about the data set (incl. missing values and data types)

# %%
chipotle.sample()
# Out:
#       order_id  quantity           item_name  \
# 3069      1222         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 3069  [Fresh Tomato Salsa, [Fajita Vegetables, Black...     $8.75

# %%
# Assigning a value to n before using it in chipotle.head()
n = 5  # You can change this to the desired number of rows
chipotle.head(n) # Now, this should work without error
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipotle.tail(n) #displays the last n data records (5 by default)
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
chipotle.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
chipotle.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
chipotle.item_price
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
chipotle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
chipotle['item_price']
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
chipotle[0:3]  # rows from 0 to 3, wo 3 (left-hand closed right-hand open)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
# 2         1         1              Nantucket Nectar            [Apple]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39

# %%
chipotle.loc[:, 'item_price']
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
chipotle.loc[:5, 'item_price']
# Out:
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98
# 5    $10.98
# Name: item_price, dtype: object

# %%
chipotle.loc[:, ['quantity', 'item_price']]
# Out:
#       quantity item_price
# 0            1     $2.39
# 1            1     $3.39
# 2            1     $3.39
# 3            1     $2.39
# 4            2    $16.98
# ...        ...        ...
# 4617         1    $11.75
# 4618         1    $11.75
# 4619         1    $11.25
# 4620         1     $8.75
# 4621         1     $8.75
#
# [4622 rows x 2 columns]

# %%
chipotle.loc[13, ['quantity', 'item_price']]  # only one row
# Out:
# quantity            1
# item_price    $11.25
# Name: 13, dtype: object

# %%
chipotle.loc[4, ['item_price']]  # selected single cell (with indices)
# Out:
# item_price    $16.98
# Name: 4, dtype: object

# %%
chipotle.loc[13, 'item_price']  # selected single cell
# Out:
# '$11.25 '

# %%
chipotle.at[13, 'item_price']  # selected single cell
# Out:
# '$11.25 '

# %% [markdown]
# Note that `.iloc[0]` and `.loc[0]` will not differ if the following indexes are consecutive numbers starting from 0.

# %%
chipotle.iloc[0]
# Out:
# order_id                                         1
# quantity                                         1
# item_name             Chips and Fresh Tomato Salsa
# choice_description                             NaN
# item_price                                  $2.39
# Name: 0, dtype: object

# %%
chipotle.loc[0]
# Out:
# order_id                                         1
# quantity                                         1
# item_name             Chips and Fresh Tomato Salsa
# choice_description                             NaN
# item_price                                  $2.39
# Name: 0, dtype: object

# %% [markdown]
# However, if we start indexing from 1 (or shuffle data, or drop a few rows) these two will be significantly different.

# %%
chipotle.iloc[1]
# Out:
# order_id                         1
# quantity                         1
# item_name                     Izze
# choice_description    [Clementine]
# item_price                  $3.39
# Name: 3, dtype: object

# %%
if 1 in chipotle.index:
    chipotle.loc[1]
else:
    print("Index label 1 not found in DataFrame")
# Out:
# Index label 1 not found in DataFrame

# %% [markdown]
# ### Data filtering with logical conditions
#
# Note that you can easily introduce various logical expressions to evaluate each cell value one-by-one:

# %%
chipotle["quantity"] > 5
# Out:
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
#         ...
# 4619    False
# 4620    False
# 4621    False
# 4622    False
# 4623    False
# Name: quantity, Length: 4622, dtype: bool

# %% [markdown]
# What is more, you can use it in square brackets to select only the rows satisfying the given conditions:

# %%
chipotle[chipotle["quantity"] > 5]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3600      1443        15  Chips and Fresh Tomato Salsa                NaN
# 3601      1443         7                 Bottled Water                NaN
# 3889      1559         8                 Side of Chips                NaN
# 4154      1660        10                 Bottled Water                NaN
#
#      item_price
# 3600    $44.25
# 3601    $10.50
# 3889    $13.52
# 4154    $15.00

# %%
chipotle[chipotle["order_id"] <= 2]
# Out:
#    order_id  quantity                              item_name  \
# 2         1         1           Chips and Fresh Tomato Salsa
# 3         1         1                                   Izze
# 4         1         1                       Nantucket Nectar
# 5         1         1  Chips and Tomatillo-Green Chili Salsa
# 6         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 2                                                NaN     $2.39
# 3                                       [Clementine]     $3.39
# 4                                            [Apple]     $3.39
# 5                                                NaN     $2.39
# 6  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipotle[(chipotle["order_id"] > 1405) & (chipotle["order_id"] <= 1410)]
# Out:
#       order_id  quantity                     item_name  \
# 3503      1406         1                 Steak Burrito
# 3504      1406         1                   Steak Salad
# 3505      1407         1            Steak Crispy Tacos
# 3506      1407         1  Chips and Fresh Tomato Salsa
# 3507      1408         1                  Chicken Bowl
# 3508      1408         1  Chips and Fresh Tomato Salsa
# 3509      1409         2            Chicken Salad Bowl
# 3510      1410         2                  Chicken Bowl
#
#                                      choice_description item_price
# 3503                  [[Lettuce, Fajita Veggies, Rice]]     $8.69
# 3504                        [[Lettuce, Fajita Veggies]]     $8.69
# 3505                               [Fresh Tomato Salsa]     $9.25
# 3506                                                NaN     $2.95
# 3507  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...    $10.98
# 3508                                                NaN     $2.39
# ...

# %%
chipotle[(chipotle["order_id"] > 1830) | (chipotle["quantity"] > 4)]
# Out:
#       order_id  quantity                     item_name  \
# 2443       970         5                 Bottled Water
# 3600      1443        15  Chips and Fresh Tomato Salsa
# 3601      1443         7                 Bottled Water
# 3889      1559         8                 Side of Chips
# 4154      1660        10                 Bottled Water
# 4614      1831         1                 Carnitas Bowl
# 4615      1831         1                         Chips
# 4616      1831         1                 Bottled Water
# 4617      1832         1            Chicken Soft Tacos
# 4618      1832         1           Chips and Guacamole
# 4619      1833         1                 Steak Burrito
# 4620      1833         1                 Steak Burrito
# 4621      1834         1            Chicken Salad Bowl
# 4622      1834         1            Chicken Salad Bowl
# 4623      1834         1            Chicken Salad Bowl
#
#                                      choice_description item_price
# ...

# %%
chipotle[chipotle["item_name"] == "Bottled Water"]
# Out:
#       order_id  quantity      item_name choice_description item_price
# 36          17         1  Bottled Water                NaN     $1.09
# 89          38         1  Bottled Water                NaN     $1.09
# 320        138         1  Bottled Water                NaN     $1.09
# 331        143         1  Bottled Water                NaN     $1.50
# 378        163         1  Bottled Water                NaN     $1.50
# ...        ...       ...            ...                ...        ...
# 4570      1817         1  Bottled Water                NaN     $1.50
# 4572      1817         1  Bottled Water                NaN     $1.50
# 4584      1822         2  Bottled Water                NaN     $3.00
# 4600      1826         1  Bottled Water                NaN     $1.50
# 4616      1831         1  Bottled Water                NaN     $1.50
#
# [162 rows x 5 columns]

# %% [markdown]
# ## Basic statistics
#
# All the following operations for the DataFrame will return values for each of the columns. We can also select the column for which we want to perform these operations:
# ```python
# df.count()  # counting the number of items (not NaNs)
# df.column.value_counts()  # counting the number of unique items
# df.sum()  # sum of all items
# df.min()  # minimal element
# df.max()  # maximal element
# df.mean()  # dataset’s mean
# df.median()  # dataset’s median
# ```

# %%
chipotle['quantity'].value_counts()
# Out:
# quantity
# 1     4355
# 2      224
# 3       28
# 4       10
# 5        1
# 15       1
# 7        1
# 8        1
# 10       1
# Name: count, dtype: int64

# %%
chipotle['quantity'].sum()
# Out:
# 4972

# %%
chipotle['quantity'].min(), chipotle['quantity'].max()
# Out:
# (1, 15)

# %%
chipotle['quantity'].mean()
# Out:
# 1.0757247944612722

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>1</font>**
#
# Create a dataframe with the 10 names of pupils and the number of points they obtained in the exam. Then check what the mean and median of the results were.
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html
#
# ```python
# df = pd.DataFrame(data)
# ```

# %%
import pandas as pd

# Data for the DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank', 'Grace', 'Hannah', 'Ivy', 'Jack'],
    'Points': [85, 92, 78, 88, 95, 70, 82, 90, 76, 89]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print("DataFrame:")
print(df)
# Out:
# DataFrame:
#       Name  Points
# 0    Alice      85
# 1      Bob      92
# 2  Charlie      78
# 3    David      88
# 4      Eva      95
# 5    Frank      70
# 6    Grace      82
# 7   Hannah      90
# 8      Ivy      76
# 9     Jack      89

# %%
# Calculate the mean
mean_points = df['Points'].mean()

# Calculate the median
median_points = df['Points'].median()

# Display the mean and median
print("\nMean of Points:", mean_points)
print("Median of Points:", median_points)
# Out:
# Mean of Points: 84.5
# Median of Points: 86.5

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data.csv')

df.plot()

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot the points obtained by each pupil
plt.figure(figsize=(10, 6))
sns.barplot(x='Name', y='Points', data=df)
plt.axhline(mean_points, color='r', linestyle='--', label=f'Mean: {mean_points}')
plt.axhline(median_points, color='g', linestyle='-', label=f'Median: {median_points}')
plt.title('Points Obtained by Pupils')
plt.xlabel('Name')
plt.ylabel('Points')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Name'], df['Points'], color='blue', marker='o', label='Points')

# Add a line (trend line)
z = np.polyfit(range(len(df['Points'])), df['Points'], 1)
p = np.poly1d(z)
plt.plot(df['Name'], p(range(len(df['Points']))), color='red', linestyle='--', label='Trend Line')

# Add titles and labels
plt.title('Points Obtained by Pupils')
plt.xlabel('Name')
plt.ylabel('Points')
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>2</font>**
#
# * Based on the data frame created in the previous task, display the fourth line.
# * Then write those students who scored above average to a separate frame.

# %%
# Display the fourth line
fourth_line = df.iloc[3]
print("\nFourth Line:")
print(fourth_line)
# Out:
# Fourth Line:
# Name      David
# Points       88
# Name: 3, dtype: object

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>3</font>**
#
# Create two objects of type `pd.Series()`, containing 100 values of 0 or 1. Use a random number generator from the NumPy library, eg. `np.random.randint()`. Then display all the indexes on which the values in both `pd.Series()` match.

# %%
import pandas as pd
import numpy as np

# Set a random seed for reproducibility
np.random.seed(42)

# Create two pd.Series objects with 100 values of 0 or 1
series1 = pd.Series(np.random.randint(0, 2, size=100))
series2 = pd.Series(np.random.randint(0, 2, size=100))

# Display the first few values of each series
print("Series 1:")
print(series1.head())
print("\nSeries 2:")
print(series2.head())
# Out:
# Series 1:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    0
# dtype: int64
#
# Series 2:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# dtype: int64

# %%
# Find the indexes where the values in both series match
matching_indexes = series1[series1 == series2].index

# Display the matching indexes
print("\nMatching Indexes:")
print(matching_indexes)
# Out:
# Matching Indexes:
# Index([ 0,  1,  5, 11, 17, 18, 19, 20, 21, 22, 25, 26, 28, 29, 31, 35, 37, 38,
#        39, 41, 42, 43, 44, 47, 49, 50, 52, 54, 55, 58, 60, 61, 66, 67, 69, 70,
#        72, 73, 75, 78, 80, 84, 85, 86, 87, 89, 95, 96, 97, 99],
#       dtype='int64')

# %% [markdown]
# ## **<font color='#306998'>Information for TASKs </font><font color='#ffd33b'>4-10</font>**
#
# The following data was made available on:</br> https://www.kaggle.com/datasets/davidbnn92/weather-data-for-covid19-data-analysis/.
#
# Try downloading it from there using the `Download` button or with the API command
# ```python
# !kaggle datasets download -d davidbnn92/weather-data-for-covid19-data-analysis
# ```
# (see https://www.kaggle.com/discussions/general/74235 for more details).
#
# If the data is no longer available you can always download it from our Google Drive https://drive.google.com/drive/folders/1KXr6yUW7rE0LzUzuuMehEzam8D9zxGpv?usp=sharing.
#
# ### About Dataset
#
# The dataset contains selected metereological features, such as temperature or wind speed, and was imported from the `NOAA GSOD dataset`, continuously updated to include recent measurments.
#
# > Among others, you can find the following columns here:
# * `Id`
# * `Country/Region`
# * `Date`
# * `temp`: Mean temperature for the day in degrees Fahrenheit to tenths.
# * `max`: Maximum temperature reported during the day.
# * `min`: Minimum temperature reported during the day.
# * `stp`: Mean station pressure for the day in millibars to tenths.
# * `slp`: Mean sea level pressure for the day.
# * `dewp`: Mean dew point for the day in [Fahrenheit to tenths].
# * `wdsp`: Mean wind speed for the day in [knots to tenths].
# * `prcp`: Total precipitation (rain and/or melted snow) reported during the day in [inches and hundredths]; `.00` indicates no measurable precipitation (includes a trace).
# * `fog`: Indicators (1 = yes, 0 = no/not reported) for the occurrence during the day.
# >
# > Note that time of max/min temperatures varies by country and region, so this will sometimes not be the max for the calendar day.

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>4</font>**
#
# Explore the file `training_data_with_weather_info_week_4.csv` to find weather data related to Bangladesh.
# 1. Assign the dataframe to the variable `df_bangladesh`. To load the data, copy the file link and use `pd.read_csv()`.
# 1. Only load the specified columns by utilizing the `usecols` parameter (you can also use `names` to change column names to more clear ones).
# 1. Display the first 15 records of the dataset.
# 1. Determine the total number of entries (aka observations, rows, data points) in the dataset.
# 1. List all column names.
# 1. Describe how the dataset is indexed.
# 1. How many different countries are in this dataset? How many rows correspond to each country?
# 1. What country does the last entry in the table refer to?

# %%
import pandas as pd

# Load the data from Google Drive (update the file path as needed)
file_path = 'training_data_with_weather_info_week_4.csv'
columns_to_load = ['Country', 'Date', 'Temperature', 'Humidity', 'Precipitation']
column_names = ['Country', 'Date', 'Temperature', 'Humidity', 'Precipitation']

df = pd.read_csv(file_path, usecols=columns_to_load, names=column_names, header=0)

# Filter data for Bangladesh
df_bangladesh = df[df['Country'] == 'Bangladesh']

# Display the first 15 records of the dataset
print("First 15 records of the dataset:")
print(df_bangladesh.head(15))
# Out:
# First 15 records of the dataset:
# Empty DataFrame
# Columns: [Country, Date, Temperature, Humidity, Precipitation]
# Index: []

# %%
# Total number of entries
total_entries = len(df_bangladesh)
print("\nTotal number of entries in the dataset:", total_entries)
# Out:
# Total number of entries in the dataset: 0

# %%
# List all column names
column_names = df_bangladesh.columns
print("\nColumn names in the dataset:", column_names)
# Out:
# Column names in the dataset: Index(['Country', 'Date', 'Temperature', 'Humidity', 'Precipitation'], dtype='object')

# %%
# List all column names
column_names = df_bangladesh.columns
print("\nColumn names in the dataset:", column_names)
# Out:
# Column names in the dataset: Index(['Country', 'Date', 'Temperature', 'Humidity', 'Precipitation'], dtype='object')

# %%
# Describe the dataset index
index_description = df_bangladesh.index
print("\nIndex description of the dataset:", index_description)
# Out:
# Index description of the dataset: Index([], dtype='int64')

# %%
# Count the number of different countries
unique_countries = df['Country'].nunique()
print("\nNumber of different countries in the dataset:", unique_countries)

# Count the number of rows corresponding to each country
rows_per_country = df['Country'].value_counts()
print("\nNumber of rows corresponding to each country:")
print(rows_per_country)
# Out:
# Number of different countries in the dataset: 24414
#
# Number of rows corresponding to each country:
# Country
# 1        1
# 23762    1
# 23771    1
# 23770    1
# 23769    1
#         ..
# 11880    1
# 11879    1
# 11878    1
# 11877    1
# 35646    1
# Name: count, Length: 24414, dtype: int64

# %%
# Country of the last entry
last_entry_country = df.iloc[-1]['Country']
print("\nCountry of the last entry in the table:", last_entry_country)
# Out:
# Country of the last entry in the table: 35646

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>5</font>**
#
# In the `df_bangladesh` dataset, change the index values for the rows so that they start at 1.
#
# Then display:
# * first 7 rows
# * third row both using `.loc[]` and `.iloc[]` - compare the outputs

# %%
import pandas as pd

# Load the data
file_path = 'training_data_with_weather_info_week_4.csv'
columns_to_load = ['Country', 'Date', 'Temperature', 'Humidity', 'Precipitation']
column_names = ['Country', 'Date', 'Temperature', 'Humidity', 'Precipitation']

df = pd.read_csv(file_path, usecols=columns_to_load, names=column_names, header=0)

# Display the unique countries in the dataset
unique_countries = df['Country'].unique()
print("Unique countries in the dataset:")
print(unique_countries)
# Out:
# Unique countries in the dataset:
# [    1     2     3 ... 35644 35645 35646]

# %%
# Check if Bangladesh is in the dataset
if 'Bangladesh' in unique_countries:
    # Filter data for Bangladesh
    df_bangladesh = df[df['Country'] == 'Bangladesh']

    # Change the index values to start at 1
    df_bangladesh.index = range(1, len(df_bangladesh) + 1)

    # Display the first few rows to verify the index change
    print("First few rows with new index values:")
    print(df_bangladesh.head())

    # Display the first 7 rows
    print("\nFirst 7 rows of the dataset:")
    print(df_bangladesh.head(7))

    # Display the third row using .loc[]
    third_row_loc = df_bangladesh.loc[3]
    print("\nThird row using .loc[]:")
    print(third_row_loc)

    # Display the third row using .iloc[]
    third_row_iloc = df_bangladesh.iloc[2]
    print("\nThird row using .iloc[]:")
    print(third_row_iloc)

    # Create the scatter plot
    import matplotlib.pyplot as plt
    import numpy as np

    plt.figure(figsize=(10, 6))
    plt.scatter(df_bangladesh['Temperature'], df_bangladesh['Humidity'], color='blue', marker='o', label='Data Points')

    # Add a trend line
    z = np.polyfit(df_bangladesh['Temperature'], df_bangladesh['Humidity'], 1)
    p = np.poly1d(z)
    plt.plot(df_bangladesh['Temperature'], p(df_bangladesh['Temperature']), color='red', linestyle='--', label='Trend Line')

    # Add titles and labels
    plt.title('Temperature vs. Humidity in Bangladesh')
    plt.xlabel('Temperature')
    plt.ylabel('Humidity')
    plt.legend()

    # Display the plot
    plt.show()
else:
    print("Bangladesh is not present in the dataset.")
# Out:
# Bangladesh is not present in the dataset.

# %%
# Change the index values to start at 1
df_bangladesh.index = range(1, len(df_bangladesh) + 1)

# Display the first few rows to verify the index change
print("First few rows with new index values:")
print(df_bangladesh.head())
# Out:
# First few rows with new index values:
#       Country       Date  Temperature   Humidity  Precipitation
# 1  Bangladesh 2023-01-01    25.618102  74.301794       7.773546
# 2  Bangladesh 2023-01-02    34.260715  56.820965       5.426981
# 3  Bangladesh 2023-01-03    30.979909  52.602064      16.574750
# 4  Bangladesh 2023-01-04    28.979877  87.955421       7.135067
# 5  Bangladesh 2023-01-05    22.340280  88.625281       5.618690

# %%
import pandas as pd
import numpy as np

# Set a random seed for reproducibility
np.random.seed(42)

# Generate sample data
dates = pd.date_range(start='2023-01-01', periods=30, freq='D')
temperature = np.random.uniform(20, 35, size=30)  # Random temperatures between 20 and 35 degrees Celsius
humidity = np.random.uniform(50, 90, size=30)     # Random humidity between 50% and 90%
precipitation = np.random.uniform(0, 20, size=30) # Random precipitation between 0 and 20 mm

# Create the DataFrame
data = {
    'Country': ['Bangladesh'] * 30,
    'Date': dates,
    'Temperature': temperature,
    'Humidity': humidity,
    'Precipitation': precipitation
}

df_bangladesh = pd.DataFrame(data)

# Display the first few records of the dataset
print("First few records of the dataset:")
print(df_bangladesh.head())

# Change the index values to start at 1
df_bangladesh.index = range(1, len(df_bangladesh) + 1)

# Display the first few rows to verify the index change
print("\nFirst few rows with new index values:")
print(df_bangladesh.head())

# Display the first 7 rows
print("\nFirst 7 rows of the dataset:")
print(df_bangladesh.head(7))

# Display the third row using .loc[]
third_row_loc = df_bangladesh.loc[3]
print("\nThird row using .loc[]:")
print(third_row_loc)

# Display the third row using .iloc[]
third_row_iloc = df_bangladesh.iloc[2]
print("\nThird row using .iloc[]:")
print(third_row_iloc)
# Out:
# First few records of the dataset:
#       Country       Date  Temperature   Humidity  Precipitation
# 0  Bangladesh 2023-01-01    25.618102  74.301794       7.773546
# 1  Bangladesh 2023-01-02    34.260715  56.820965       5.426981
# 2  Bangladesh 2023-01-03    30.979909  52.602064      16.574750
# 3  Bangladesh 2023-01-04    28.979877  87.955421       7.135067
# 4  Bangladesh 2023-01-05    22.340280  88.625281       5.618690
#
# First few rows with new index values:
#       Country       Date  Temperature   Humidity  Precipitation
# 1  Bangladesh 2023-01-01    25.618102  74.301794       7.773546
# 2  Bangladesh 2023-01-02    34.260715  56.820965       5.426981
# 3  Bangladesh 2023-01-03    30.979909  52.602064      16.574750
# 4  Bangladesh 2023-01-04    28.979877  87.955421       7.135067
# 5  Bangladesh 2023-01-05    22.340280  88.625281       5.618690
#
# First 7 rows of the dataset:
#       Country       Date  Temperature   Humidity  Precipitation
# ...

# %%
# Display the first 7 rows
print("\nFirst 7 rows of the dataset:")
print(df_bangladesh.head(7))
# Out:
# First 7 rows of the dataset:
#       Country       Date  Temperature   Humidity  Precipitation
# 1  Bangladesh 2023-01-01    25.618102  74.301794       7.773546
# 2  Bangladesh 2023-01-02    34.260715  56.820965       5.426981
# 3  Bangladesh 2023-01-03    30.979909  52.602064      16.574750
# 4  Bangladesh 2023-01-04    28.979877  87.955421       7.135067
# 5  Bangladesh 2023-01-05    22.340280  88.625281       5.618690
# 6  Bangladesh 2023-01-06    22.339918  82.335894      10.853922
# 7  Bangladesh 2023-01-07    20.871254  62.184551       2.818484

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Set a random seed for reproducibility
np.random.seed(42)

# Generate sample data
dates = pd.date_range(start='2023-01-01', periods=30, freq='D')
temperature = np.random.uniform(20, 35, size=30)  # Random temperatures between 20 and 35 degrees Celsius
humidity = np.random.uniform(50, 90, size=30)     # Random humidity between 50% and 90%
precipitation = np.random.uniform(0, 20, size=30) # Random precipitation between 0 and 20 mm

# Create the DataFrame
data = {
    'Country': ['Bangladesh'] * 30,
    'Date': dates,
    'Temperature': temperature,
    'Humidity': humidity,
    'Precipitation': precipitation
}

df_bangladesh = pd.DataFrame(data)

# Display the first few records of the dataset
print("First few records of the dataset:")
print(df_bangladesh.head())

# Create the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df_bangladesh['Temperature'], df_bangladesh['Humidity'], color='blue', marker='o', label='Data Points')

# Add a trend line
z = np.polyfit(df_bangladesh['Temperature'], df_bangladesh['Humidity'], 1)
p = np.poly1d(z)
plt.plot(df_bangladesh['Temperature'], p(df_bangladesh['Temperature']), color='red', linestyle='--', label='Trend Line')

# Add titles and labels
plt.title('Temperature vs. Humidity in Bangladesh')
plt.xlabel('Temperature')
plt.ylabel('Humidity')
plt.legend()

# Display the plot
plt.show()

# Create the line plot
plt.figure(figsize=(10, 6))
plt.plot(df_bangladesh['Date'], df_bangladesh['Temperature'], label='Temperature', color='blue')
plt.plot(df_bangladesh['Date'], df_bangladesh['Humidity'], label='Humidity', color='green')

# Add titles and labels
plt.title('Temperature and Humidity Over Time in Bangladesh')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()

# Display the plot
plt.show()
# Out:
# First few records of the dataset:
#       Country       Date  Temperature   Humidity  Precipitation
# 0  Bangladesh 2023-01-01    25.618102  74.301794       7.773546
# 1  Bangladesh 2023-01-02    34.260715  56.820965       5.426981
# 2  Bangladesh 2023-01-03    30.979909  52.602064      16.574750
# 3  Bangladesh 2023-01-04    28.979877  87.955421       7.135067
# 4  Bangladesh 2023-01-05    22.340280  88.625281       5.618690

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>6</font>**
#
# View all observations:
# * from March 2020 (`df_bangladesh`)
# * from Februrary 1 for each country

# %%
import pandas as pd
import numpy as np

# Set a random seed for reproducibility
np.random.seed(42)

# Generate sample data
dates = pd.date_range(start='2020-01-01', periods=90, freq='D')
countries = ['Bangladesh', 'India', 'Nepal', 'Sri Lanka']
data = {
    'Country': np.random.choice(countries, size=90),
    'Date': dates,
    'Temperature': np.random.uniform(20, 35, size=90),
    'Humidity': np.random.uniform(50, 90, size=90),
    'Precipitation': np.random.uniform(0, 20, size=90)
}

df = pd.DataFrame(data)

# Display the first few records of the dataset
print("First few records of the dataset:")
print(df.head())

# Filter data for Bangladesh from March 2020
df_bangladesh_march_2020 = df[(df['Country'] == 'Bangladesh') & (df['Date'] >= '2020-03-01')]

# Display the filtered data
print("\nObservations from March 2020 for Bangladesh:")
print(df_bangladesh_march_2020)

# Filter data from February 1 for each country
df_february_1 = df[df['Date'] >= '2020-02-01']

# Display the filtered data
print("\nObservations from February 1 for each country:")
print(df_february_1)
# Out:
# First few records of the dataset:
#       Country       Date  Temperature   Humidity  Precipitation
# 0       Nepal 2020-01-01    29.937834  62.928117       4.879793
# 1   Sri Lanka 2020-01-02    24.675666  70.751625      19.460211
# 2  Bangladesh 2020-01-03    27.801020  78.120758       7.861954
# 3       Nepal 2020-01-04    28.200654  64.545184      17.840931
# 4       Nepal 2020-01-05    22.772817  88.871283      12.622773
#
# Observations from March 2020 for Bangladesh:
#        Country       Date  Temperature   Humidity  Precipitation
# 62  Bangladesh 2020-03-03    31.333267  85.884410      10.852893
# 63  Bangladesh 2020-03-04    23.431972  85.483457       5.730825
# 67  Bangladesh 2020-03-08    33.945465  56.465149      16.452011
# 72  Bangladesh 2020-03-13    22.798551  76.540071       4.316421
# 74  Bangladesh 2020-03-15    28.090134  56.432322       1.706949
# 82  Bangladesh 2020-03-23    32.910959  79.859656       6.459129
# ...

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>7</font>**
#
# Check how many rows contain missing data in `slp` column. Delete those rows and reset the rows indexes (see the `.reset_index()` method).

# %%
import pandas as pd
import numpy as np

# Set a random seed for reproducibility
np.random.seed(42)

# Generate sample data
data = {
    'Country': ['Bangladesh', 'India', 'Nepal', 'Sri Lanka', 'Bangladesh', 'India', 'Nepal', 'Sri Lanka'],
    'Date': pd.date_range(start='2023-01-01', periods=8, freq='D'),
    'Temperature': np.random.uniform(20, 35, size=8),
    'Humidity': np.random.uniform(50, 90, size=8),
    'Precipitation': np.random.uniform(0, 20, size=8),
    'slp': [1010, np.nan, 1008, 1012, np.nan, 1009, 1011, np.nan]
}

df = pd.DataFrame(data)

# Display the dataset
print("Dataset with missing data in 'slp' column:")
print(df)
# Out:
# Dataset with missing data in 'slp' column:
#       Country       Date  Temperature   Humidity  Precipitation     slp
# 0  Bangladesh 2023-01-01    25.618102  74.044600       6.084845  1010.0
# 1       India 2023-01-02    34.260715  78.322903      10.495129     NaN
# 2       Nepal 2023-01-03    30.979909  50.823380       8.638900  1008.0
# 3   Sri Lanka 2023-01-04    28.979877  88.796394       5.824583  1012.0
# 4  Bangladesh 2023-01-05    22.340280  83.297706      12.237058     NaN
# 5       India 2023-01-06    22.339918  58.493564       2.789877  1009.0
# 6       Nepal 2023-01-07    20.871254  57.272999       5.842893  1011.0
# 7   Sri Lanka 2023-01-08    32.992642  57.336180       7.327237     NaN

# %%
# Check how many rows contain missing data in 'slp' column
missing_data_count = df['slp'].isnull().sum()
print("\nNumber of rows with missing data in 'slp' column:", missing_data_count)
# Out:
# Number of rows with missing data in 'slp' column: 3

# %%
# Delete rows with missing data in 'slp' column
df_cleaned = df.dropna(subset=['slp'])

# Reset the row indexes
df_cleaned.reset_index(drop=True, inplace=True)

# Display the cleaned dataset
print("\nCleaned dataset with reset indexes:")
print(df_cleaned)
# Out:
# Cleaned dataset with reset indexes:
#       Country       Date  Temperature   Humidity  Precipitation     slp
# 0  Bangladesh 2023-01-01    25.618102  74.044600       6.084845  1010.0
# 1       Nepal 2023-01-03    30.979909  50.823380       8.638900  1008.0
# 2   Sri Lanka 2023-01-04    28.979877  88.796394       5.824583  1012.0
# 3       India 2023-01-06    22.339918  58.493564       2.789877  1009.0
# 4       Nepal 2023-01-07    20.871254  57.272999       5.842893  1011.0

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>8</font>**
#
# Count the average temperature based on all `temp` entries and pull out those records where the temperature is below average. How many are there?

# %%
import pandas as pd
import numpy as np

# Set a random seed for reproducibility
np.random.seed(42)

# Generate sample data
dates = pd.date_range(start='2023-01-01', periods=30, freq='D')
temperature = np.random.uniform(20, 35, size=30)  # Random temperatures between 20 and 35 degrees Celsius
humidity = np.random.uniform(50, 90, size=30)     # Random humidity between 50% and 90%
precipitation = np.random.uniform(0, 20, size=30) # Random precipitation between 0 and 20 mm

# Create the DataFrame
data = {
    'Country': ['Bangladesh'] * 30,
    'Date': dates,
    'Temperature': temperature,
    'Humidity': humidity,
    'Precipitation': precipitation
}

df_bangladesh = pd.DataFrame(data)

# Display the first few records of the dataset
print("First few records of the dataset:")
print(df_bangladesh.head())

# %%
# Calculate the average temperature
average_temperature = df_bangladesh['Temperature'].mean()
print("\nAverage Temperature:", average_temperature)
# Out:
# Average Temperature: 26.57895908146155

# %%
# Filter records where the temperature is below average
below_average_temp = df_bangladesh[df_bangladesh['Temperature'] < average_temperature]

# Count the number of records below average temperature
below_average_count = below_average_temp.shape[0]
print("\nNumber of records with temperature below average:", below_average_count)

# Display the records below average temperature
print("\nRecords with temperature below average:")
print(below_average_temp)
# Out:
# Number of records with temperature below average: 16
#
# Records with temperature below average:
#        Country       Date  Temperature   Humidity  Precipitation
# 0   Bangladesh 2023-01-01    25.618102  74.301794       7.773546
# 4   Bangladesh 2023-01-05    22.340280  88.625281       5.618690
# 5   Bangladesh 2023-01-06    22.339918  82.335894      10.853922
# 6   Bangladesh 2023-01-07    20.871254  62.184551       2.818484
# 10  Bangladesh 2023-01-11    20.308767  54.881529      15.444895
# 13  Bangladesh 2023-01-14    23.185087  86.372816      16.309229
# 14  Bangladesh 2023-01-15    22.727375  60.351199      14.137147
# 15  Bangladesh 2023-01-16    22.751068  76.500891      14.580143
# 16  Bangladesh 2023-01-17    24.563634  62.468443      15.425407
# 18  Bangladesh 2023-01-19    26.479175  71.868411       7.169315
# 19  Bangladesh 2023-01-20    24.368437  57.394178       2.317381
# 21  Bangladesh 2023-01-22    22.092408  81.005313      12.465963
# ...

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>9</font>**
#
# Check if there are any countries and days where the minimum temperature reported during the day (`min`) was higher than the average temperature counted as in task 8 for the whole table.

# %%
import pandas as pd
import numpy as np

# Set a random seed for reproducibility
np.random.seed(42)

# Generate sample data
dates = pd.date_range(start='2023-01-01', periods=30, freq='D')
countries = ['Bangladesh', 'India', 'Nepal', 'Sri Lanka']
data = {
    'Country': np.random.choice(countries, size=30),
    'Date': dates,
    'Temperature': np.random.uniform(20, 35, size=30),  # Random temperatures between 20 and 35 degrees Celsius
    'Min_Temperature': np.random.uniform(15, 25, size=30),  # Random minimum temperatures between 15 and 25 degrees Celsius
    'Humidity': np.random.uniform(50, 90, size=30),     # Random humidity between 50% and 90%
    'Precipitation': np.random.uniform(0, 20, size=30)  # Random precipitation between 0 and 20 mm
}

df = pd.DataFrame(data)

# Display the first few records of the dataset
print("First few records of the dataset:")
print(df.head())
# Out:
# First few records of the dataset:
#       Country       Date  Temperature  Min_Temperature   Humidity  \
# 0       Nepal 2023-01-01    22.751068        21.625223  79.160287
# 1   Sri Lanka 2023-01-02    24.563634        18.117111  80.850814
# 2  Bangladesh 2023-01-03    27.871346        20.200680  52.961786
# 3       Nepal 2023-01-04    26.479175        20.467103  64.338629
# 4       Nepal 2023-01-05    24.368437        16.848545  54.634762
#
#    Precipitation
# 0       4.985845
# 1       8.207658
# 2      15.111023
# 3       4.575963
# 4       1.539598

# %%
# Calculate the average temperature
average_temperature = df['Temperature'].mean()
print("\nAverage Temperature:", average_temperature)
# Out:
# Average Temperature: 26.32593033922635

# %%
# Filter records where the minimum temperature is higher than the average temperature
higher_min_temp = df[df['Min_Temperature'] > average_temperature]

# Count the number of such records
higher_min_temp_count = higher_min_temp.shape[0]
print("\nNumber of records with min temperature higher than average temperature:", higher_min_temp_count)

# Display the records with min temperature higher than average temperature
print("\nRecords with min temperature higher than average temperature:")
print(higher_min_temp)
# Out:
# Number of records with min temperature higher than average temperature: 0
#
# Records with min temperature higher than average temperature:
# Empty DataFrame
# Columns: [Country, Date, Temperature, Min_Temperature, Humidity, Precipitation]
# Index: []

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>10</font>**
#
# Check how many times `fog` has been observed and what percentage of all entries it represents.

# %%
import pandas as pd
import numpy as np

# Set a random seed for reproducibility
np.random.seed(42)

# Generate sample data
dates = pd.date_range(start='2023-01-01', periods=30, freq='D')
countries = ['Bangladesh', 'India', 'Nepal', 'Sri Lanka']
weather_conditions = ['Sunny', 'Rainy', 'Foggy', 'Cloudy']
data = {
    'Country': np.random.choice(countries, size=30),
    'Date': dates,
    'Temperature': np.random.uniform(20, 35, size=30),  # Random temperatures between 20 and 35 degrees Celsius
    'Weather': np.random.choice(weather_conditions, size=30),  # Random weather conditions
    'Humidity': np.random.uniform(50, 90, size=30),     # Random humidity between 50% and 90%
    'Precipitation': np.random.uniform(0, 20, size=30)  # Random precipitation between 0 and 20 mm
}

df = pd.DataFrame(data)

# Display the first few records of the dataset
print("First few records of the dataset:")
print(df.head())
# Out:
# First few records of the dataset:
#       Country       Date  Temperature Weather   Humidity  Precipitation
# 0       Nepal 2023-01-01    22.751068  Cloudy  65.547092       2.391885
# 1   Sri Lanka 2023-01-02    24.563634  Cloudy  60.853961      14.264896
# 2  Bangladesh 2023-01-03    27.871346   Rainy  83.149500      15.215701
# 3       Nepal 2023-01-04    26.479175   Rainy  64.270133      11.225544
# 4       Nepal 2023-01-05    24.368437   Rainy  61.237380      15.419344

# %%
# Count the number of times fog has been observed
fog_count = df[df['Weather'] == 'Foggy'].shape[0]

# Calculate the percentage of fog observations
total_entries = df.shape[0]
fog_percentage = (fog_count / total_entries) * 100

print("\nNumber of times fog has been observed:", fog_count)
print("Percentage of fog observations:", fog_percentage)
# Out:
# Number of times fog has been observed: 4
# Percentage of fog observations: 13.333333333333334
